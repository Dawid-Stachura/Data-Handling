# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
url = 'https://raw.githubusercontent.com/sivabalanb/Data-Analysis-with-Pandas-and-Python/master/employees.csv'
data = pd.read_csv(url)
data.head(10)
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances  Female    8/8/2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team
# 0              True             Marketing
# 1              True                   NaN
# 2             False               Finance
# 3              True               Finance
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data['First Name'].unique()
# Out:
# array(['Douglas', 'Thomas', 'Maria', 'Jerry', 'Larry', 'Dennis', 'Ruby',
#        nan, 'Angela', 'Frances', 'Louise', 'Julie', 'Brandon', 'Gary',
#        'Kimberly', 'Lillian', 'Jeremy', 'Shawn', 'Diana', 'Donna', 'Lois',
#        'Matthew', 'Joshua', 'John', 'Craig', 'Scott', 'Terry', 'Benjamin',
#        'Christina', 'Joyce', 'Jean', 'Theresa', 'Rachel', 'Linda',
#        'Stephanie', 'Michael', 'Christine', 'Beverly', 'Marilyn',
#        'Cynthia', 'Roger', 'Bruce', 'Kathy', 'Clarence', 'Chris', 'Nancy',
#        'Todd', 'Alan', 'Sara', 'Karen', 'Carl', 'Henry', 'Irene', 'Paula',
#        'Denise', 'Kathleen', 'Steve', 'Jose', 'Johnny', 'Bobby', 'Bonnie',
#        'Margaret', 'Charles', 'Robin', 'Gerald', 'Christopher', 'Steven',
#        'Doris', 'Annie', 'Janice', 'James', 'Virginia', 'Harry',
#        'Heather', 'Laura', 'Tina', 'Harold', 'Melissa', 'Aaron', 'Jack',
#        'Phyllis', 'Paul', 'Russell', 'Shirley', 'Willie', 'Ashley',
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data['Salary'].unique()
# Out:
# array([ 97308,  61933, 130590, 138705, 101004, 115163,  65476,  45906,
#         95570, 139852,  63241, 102508, 112807, 109831,  41426,  59414,
#         90370, 111737, 132940,  81014,  64714, 100612,  90816, 125792,
#         97950,  37076,  37598, 122367, 124008,  79529, 118780,  88657,
#        122340, 119082,  95734,  85182, 142032,  57427,  36844, 122173,
#         99283,  66582, 121918,  73524, 145146,  88010, 114796,  66820,
#         93581, 113590,  94976,  41126,  49339,  40341,  83677, 102488,
#        130276,  64715,  72670,  66851,  48866, 106862,  58112,  35203,
#         77834,  61310, 125250,  51178,  84834, 100863,  84692, 118172,
#         54043,  90582,  62096, 104897, 131604, 107391, 114797, 115814,
#        137126,  47369,  35095, 148115,  83072, 100238, 103495, 144887,
#         64088,  51082,  91719, 128771, 119009, 111858, 130620,  43026,
#        142321, 140371, 100705,  77544,  48109,  61602, 103902, 136984,
# ...

# %%
data['Bonus %'].unique()
# Out:
# array([ 6.945,  4.17 , 11.858,  9.34 ,  1.389, 10.125, 10.012, 11.598,
#        18.523,  7.524, 15.132, 12.637, 17.492,  5.831, 14.543,  1.256,
#         7.369,  6.414, 19.082,  1.894,  4.934, 13.645, 18.816,  5.042,
#        13.873, 18.576,  7.757,  5.218, 13.464,  7.008,  9.096, 12.752,
#         6.417, 16.18 , 19.096, 16.675, 12.599,  9.557,  5.574,  7.797,
#         2.665, 11.308, 15.835,  5.207,  7.482, 13.886,  6.796,  9.   ,
#         6.083,  3.055, 13.83 , 14.009,  1.695, 17.578,  8.999, 17.653,
#        16.084, 15.107,  1.481, 11.279,  4.271,  3.699, 19.414, 18.04 ,
#        18.771, 12.428,  2.672,  9.735, 14.33 ,  4.382,  6.617, 16.194,
#         3.833,  4.709, 17.029,  5.118,  7.353,  1.26 ,  5.965,  4.99 ,
#        15.602, 14.822,  8.379,  6.539,  7.511,  3.887, 17.29 ,  8.276,
#         6.155, 11.955, 11.583,  8.309, 12.506,  1.601,  7.03 , 14.166,
#         1.737, 10.62 , 16.961, 12.447, 14.995, 11.849, 12.159,  8.932,
# ...

# %%
data['Senior Management'].unique()
# Out:
# array([True, False, nan], dtype=object)

# %%
data['Team'].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
data.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
data = data.drop(columns=['Start Date', 'Last Login Time'])
data
# Out:
#     First Name  Gender  Salary  Bonus % Senior Management  \
# 0      Douglas    Male   97308    6.945              True
# 1       Thomas    Male   61933    4.170              True
# 2        Maria  Female  130590   11.858             False
# 3        Jerry    Male  138705    9.340              True
# 4        Larry    Male  101004    1.389              True
# ..         ...     ...     ...      ...               ...
# 995      Henry     NaN  132483   16.655             False
# 996    Phillip    Male   42392   19.675             False
# 997    Russell    Male   96914    1.421             False
# 998      Larry    Male   60500   11.985             False
# 999     Albert    Male  129949   10.169              True
#
#                      Team
# 0               Marketing
# 1                     NaN
# 2                 Finance
# 3                 Finance
# 4         Client Services
# ..                    ...
# 995          Distribution
# 996               Finance
# ...

# %%
data['Gnder_check'] = data['First Name'].str[-1]
data.head(5)
# Out:
#   First Name  Gender  Salary  Bonus % Senior Management             Team  \
# 0    Douglas    Male   97308    6.945              True        Marketing
# 1     Thomas    Male   61933    4.170              True              NaN
# 2      Maria  Female  130590   11.858             False          Finance
# 3      Jerry    Male  138705    9.340              True          Finance
# 4      Larry    Male  101004    1.389              True  Client Services
#
#   Gnder_check
# 0           s
# 1           s
# 2           a
# 3           y
# 4           y

# %%
data.loc[data['Gender'].isna() & ((data['Gnder_check']=='e') | (data['Gnder_check']=='a')), 'var']= 'Likely Female'

# %%
Names = data.loc[data['var']=='Likely Female']
Names
# Out:
#     First Name Gender  Salary  Bonus % Senior Management  \
# 22      Joshua    NaN   90816   18.816              True
# 31       Joyce    NaN   88657   12.752             False
# 41   Christine    NaN   66582   11.308              True
# 60       Paula    NaN   48866    4.271             False
# 69       Irene    NaN  100863    4.382              True
# 86       Annie    NaN  103495   17.290              True
# 90      Janice    NaN   91719   11.583              True
# 93    Virginia    NaN  111858    1.601              True
# 97       Laura    NaN  140371   10.620              True
# 143     Teresa    NaN  140013    8.689              True
# 144     Nicole    NaN  122717   12.452             False
# 192    Barbara    NaN   99326   16.475              True
# 230     George    NaN   38375    8.999             False
# 247     Brenda    NaN  106115    3.742              True
# 277     Brenda    NaN   82439   19.062             False
# ...

# %%
Names['First Name'].value_counts().plot(kind='barh', figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
Names
# Out:
#     First Name Gender  Salary  Bonus % Senior Management  \
# 22      Joshua    NaN   90816   18.816              True
# 31       Joyce    NaN   88657   12.752             False
# 41   Christine    NaN   66582   11.308              True
# 60       Paula    NaN   48866    4.271             False
# 69       Irene    NaN  100863    4.382              True
# 86       Annie    NaN  103495   17.290              True
# 90      Janice    NaN   91719   11.583              True
# 93    Virginia    NaN  111858    1.601              True
# 97       Laura    NaN  140371   10.620              True
# 143     Teresa    NaN  140013    8.689              True
# 144     Nicole    NaN  122717   12.452             False
# 192    Barbara    NaN   99326   16.475              True
# 230     George    NaN   38375    8.999             False
# 247     Brenda    NaN  106115    3.742              True
# 277     Brenda    NaN   82439   19.062             False
# ...

# %%
data.loc[22,'Gender'] = 'Male'
data.loc[230, 'Gender'] = 'Male'
data.loc[659, 'Gender'] = 'Male'
data.loc[407, 'Gender'] = 'Male'

# %%
data.loc[data['Gender'].isna() & ((data['Gnder_check']=='e') | (data['Gnder_check']=='a')), 'Gender']= 'Female'
data.loc[data['Gender'].isna() & ((data['Gnder_check']=='e') | (data['Gnder_check']=='a'))]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Salary, Bonus %, Senior Management, Team, Gnder_check, var]
# Index: []

# %%
Names2 = data.loc[(data['Gnder_check']!='e') & (data['Gnder_check']!='a')]
Names2
# Out:
#     First Name Gender  Salary  Bonus % Senior Management  \
# 0      Douglas   Male   97308    6.945              True
# 1       Thomas   Male   61933    4.170              True
# 3        Jerry   Male  138705    9.340              True
# 4        Larry   Male  101004    1.389              True
# 5       Dennis   Male  115163   10.125             False
# ..         ...    ...     ...      ...               ...
# 995      Henry    NaN  132483   16.655             False
# 996    Phillip   Male   42392   19.675             False
# 997    Russell   Male   96914    1.421             False
# 998      Larry   Male   60500   11.985             False
# 999     Albert   Male  129949   10.169              True
#
#                      Team Gnder_check  var
# 0               Marketing           s  NaN
# 1                     NaN           s  NaN
# 3                 Finance           y  NaN
# 4         Client Services           y  NaN
# 5                   Legal           s  NaN
# ...

# %%
Names2['First Name'].value_counts(ascending=True).plot(kind='barh', figsize=(6,35))
# Out:
# <AxesSubplot:>

# %%
#n,y,h,n,y,s,l,t,i,r # last letters for possible female names

# %%
data.loc[data['Gender'].isna() & (data['Gnder_check']=='h'), 'var']= 'Likely Female2'
Names3 = data.loc[data['var']=='Likely Female2']
Names3
# Out:
#     First Name Gender  Salary  Bonus % Senior Management             Team  \
# 183       Ruth    NaN   98233    2.518              True     Distribution
# 263      Sarah    NaN   58295   14.603              True      Engineering
# 404      Sarah    NaN  109980    8.860             False            Sales
# 417      Sarah    NaN   37748    9.047             False  Human Resources
# 456    Deborah    NaN  101457    6.662             False      Engineering
# 611  Elizabeth    NaN   52730   12.525             False        Marketing
# 669     Joseph    NaN   86564   11.879              True              NaN
# 897    Kenneth    NaN   95296   10.146             False          Finance
# 939      Ralph    NaN   70635    2.147             False  Client Services
#
#     Gnder_check             var
# 183           h  Likely Female2
# 263           h  Likely Female2
# 404           h  Likely Female2
# 417           h  Likely Female2
# 456           h  Likely Female2
# ...

# %%
Names3['First Name'].value_counts(ascending=True).plot(kind='barh', figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
Names3
# Out:
#     First Name Gender  Salary  Bonus % Senior Management             Team  \
# 183       Ruth    NaN   98233    2.518              True     Distribution
# 263      Sarah    NaN   58295   14.603              True      Engineering
# 404      Sarah    NaN  109980    8.860             False            Sales
# 417      Sarah    NaN   37748    9.047             False  Human Resources
# 456    Deborah    NaN  101457    6.662             False      Engineering
# 611  Elizabeth    NaN   52730   12.525             False        Marketing
# 669     Joseph    NaN   86564   11.879              True              NaN
# 897    Kenneth    NaN   95296   10.146             False          Finance
# 939      Ralph    NaN   70635    2.147             False  Client Services
#
#     Gnder_check             var
# 183           h  Likely Female2
# 263           h  Likely Female2
# 404           h  Likely Female2
# 417           h  Likely Female2
# 456           h  Likely Female2
# ...

# %%
data.loc[183,'Gender'] = 'Female'
data.loc[263, 'Gender'] = 'Female'
data.loc[404, 'Gender'] = 'Female'
data.loc[415, 'Gender'] = 'Female'
data.loc[417, 'Gender'] = 'Female'
data.loc[456, 'Gender'] = 'Female'
data.loc[482, 'Gender'] = 'Female'
data.loc[514, 'Gender'] = 'Female'
data.loc[611, 'Gender'] = 'Female'
data.loc[660, 'Gender'] = 'Female'
data.loc[699, 'Gender'] = 'Female'
data.loc[744, 'Gender'] = 'Female'

# %%
data.loc[(data['var']=='Likely Female2') & data['Gender'].isna()]
# Out:
#     First Name Gender  Salary  Bonus % Senior Management             Team  \
# 669     Joseph    NaN   86564   11.879              True              NaN
# 897    Kenneth    NaN   95296   10.146             False          Finance
# 939      Ralph    NaN   70635    2.147             False  Client Services
#
#     Gnder_check             var
# 669           h  Likely Female2
# 897           h  Likely Female2
# 939           h  Likely Female2

# %%
data.loc[(data['var']=='Likely Female2') & data['Gender'].isna(),'Gender']='Male'
data.loc[(data['var']=='Likely Female2') & data['Gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Salary, Bonus %, Senior Management, Team, Gnder_check, var]
# Index: []

# %%
data.isnull().sum()
# Out:
# First Name            67
# Gender                84
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# Gnder_check           67
# var                  945
# dtype: int64

# %%
First_Name = data.loc[data['First Name'].isna()]
First_Name
# Out:
#     First Name  Gender  Salary  Bonus % Senior Management             Team  \
# 7          NaN  Female   45906   11.598               NaN          Finance
# 23         NaN    Male  125792    5.042               NaN              NaN
# 25         NaN    Male   37076   18.576               NaN  Client Services
# 32         NaN    Male  122340    6.417               NaN              NaN
# 39         NaN    Male  122173    7.797               NaN  Client Services
# ..         ...     ...     ...      ...               ...              ...
# 902        NaN    Male  103877    6.322               NaN     Distribution
# 925        NaN  Female   95866   19.388               NaN            Sales
# 946        NaN  Female  133472   16.941               NaN     Distribution
# 947        NaN    Male  107351    5.329               NaN        Marketing
# 951        NaN  Female  143638    9.662               NaN              NaN
#
#     Gnder_check  var
# 7           NaN  NaN
# 23          NaN  NaN
# ...

# %%
data.loc[(data['First Name'].isna() & data['Gender'].isna()),'Gender'] = 'No Gender'

# %%
data.loc[data['Gender'].isna() & ((data['Gnder_check']=='n') & (data['Gnder_check']=='s')), 'var']= 'Likely Female3'
Names4 = data.loc[data['var']=='Likely Female3']
Names4
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Salary, Bonus %, Senior Management, Team, Gnder_check, var]
# Index: []

# %%
Gender = data.loc[data['Gender'].isna()]
Gender['First Name'].value_counts(ascending=True).plot(kind='barh', figsize=(8, 12))
# Out:
# <AxesSubplot:>

# %%
data.loc[data['Gender'].isna() & (data['Gnder_check']=='n'), 'var']= 'Likely Female3'
Names4 = data.loc[data['var']=='Likely Female3']
Names4
# Out:
#     First Name Gender  Salary  Bonus % Senior Management  \
# 53        Alan    NaN   40341   17.578              True
# 64    Kathleen    NaN   77834   18.771             False
# 121   Kathleen    NaN  119735   18.740             False
# 151    Brandon    NaN  121333   15.295             False
# 161    Marilyn    NaN  103386   11.451             False
# 239    Lillian    NaN   64164   17.612             False
# 251     Sharon    NaN   83658    6.513             False
# 303       Joan    NaN   38712    3.657             False
# 363     Justin    NaN   96978   13.865             False
# 389     Sharon    NaN   97635   10.413              True
# 527      Helen    NaN   45724    1.022             False
# 631      Jason    NaN   82873    1.869             False
# 683      Robin    NaN   41230    6.611              True
# 701      Robin    NaN   93201   11.712              True
# 703    Brandon    NaN   73587    9.769              True
# ...

# %%
data.loc[15,'Gender'] = 'Female'
data.loc[64, 'Gender'] = 'Female'
data.loc[121, 'Gender'] = 'Female'
data.loc[161, 'Gender'] = 'Female'
data.loc[239, 'Gender'] = 'Female'
data.loc[251, 'Gender'] = 'Female'
data.loc[303, 'Gender'] = 'Female'
data.loc[389, 'Gender'] = 'Female'
data.loc[527, 'Gender'] = 'Female'
data.loc[683, 'Gender'] = 'Female'
data.loc[701, 'Gender'] = 'Female'

# %%
data.loc[data['Gender'].isna() & (data['Gnder_check']=='n'), 'Gender'] = 'Male'

# %%
data.loc[data['Gender'].isnull()]
# Out:
#     First Name Gender  Salary  Bonus % Senior Management  \
# 20        Lois    NaN   64714    4.934              True
# 27       Scott    NaN  122367    5.218             False
# 49       Chris    NaN  113590    3.055             False
# 70        Todd    NaN   84692    6.617             False
# 80      Gerald    NaN  137126   15.602              True
# 91       James    NaN  128771    8.309             False
# 108    Russell    NaN  133980   12.396              True
# 148    Patrick    NaN  124488   14.837              True
# 153     Victor    NaN   84546   10.489              True
# 159      James    NaN   68501   14.316             False
# 168      Peter    NaN   38989    7.017              True
# 218    Gregory    NaN   98865   10.628              True
# 240    Phyllis    NaN   94088   19.107             False
# 246       Fred    NaN   59937   12.045              True
# 250      Randy    NaN  133943    8.940              True
# ...

# %%
data.loc[20,'Gender'] = 'Female'
data.loc[361, 'Gender'] = 'Female'
data.loc[366, 'Gender'] = 'Female'
data.loc[749, 'Gender'] = 'Female'

# %%
Male_names = data.loc[data['Gender'].isnull()]
Male_names['First Name'].value_counts(ascending=True).plot(kind='barh', figsize=(8,10))
# Out:
# <AxesSubplot:>

# %%
data['Gender'] = data['Gender'].fillna('Male')
data.isnull().sum()
# Out:
# First Name            67
# Gender                 0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# Gnder_check           67
# var                  924
# dtype: int64

# %%
data['First Name'] = data['First Name'].fillna('No Name')

# %%
management = data.loc[data['Senior Management'].notnull()]

# %%
sns.boxplot(x=data['Senior Management'], y=data['Salary'])
# Out:
# <AxesSubplot:xlabel='Senior Management', ylabel='Salary'>

# %%
management2 = data.loc[data['Senior Management'].notnull()&data['Bonus %'].notnull()]
sns.boxplot(x=data['Senior Management'], y=data['Bonus %'])
# Out:
# <AxesSubplot:xlabel='Senior Management', ylabel='Bonus %'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   object
#  2   Salary             1000 non-null   int64
#  3   Bonus %            1000 non-null   float64
#  4   Senior Management  933 non-null    object
#  5   Team               957 non-null    object
#  6   Gnder_check        933 non-null    object
#  7   var                76 non-null     object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
data.Salary.unique()
# Out:
# array([ 97308,  61933, 130590, 138705, 101004, 115163,  65476,  45906,
#         95570, 139852,  63241, 102508, 112807, 109831,  41426,  59414,
#         90370, 111737, 132940,  81014,  64714, 100612,  90816, 125792,
#         97950,  37076,  37598, 122367, 124008,  79529, 118780,  88657,
#        122340, 119082,  95734,  85182, 142032,  57427,  36844, 122173,
#         99283,  66582, 121918,  73524, 145146,  88010, 114796,  66820,
#         93581, 113590,  94976,  41126,  49339,  40341,  83677, 102488,
#        130276,  64715,  72670,  66851,  48866, 106862,  58112,  35203,
#         77834,  61310, 125250,  51178,  84834, 100863,  84692, 118172,
#         54043,  90582,  62096, 104897, 131604, 107391, 114797, 115814,
#        137126,  47369,  35095, 148115,  83072, 100238, 103495, 144887,
#         64088,  51082,  91719, 128771, 119009, 111858, 130620,  43026,
#        142321, 140371, 100705,  77544,  48109,  61602, 103902, 136984,
# ...

# %%
stats = data.loc[data['Salary'].notnull()&data['Team'].notnull()]

# %%
stats['Salary'].astype(int)
# Out:
# 0       97308
# 2      130590
# 3      138705
# 4      101004
# 5      115163
#         ...
# 995    132483
# 996     42392
# 997     96914
# 998     60500
# 999    129949
# Name: Salary, Length: 957, dtype: int32

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x=data['Salary'], y=data['Team'])
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Team'>

# %%
plt.figure(figsize=(14,10))

Salary_notnull = data.loc[data['Salary'].notnull()&data['Bonus %'].notnull()]
sns.heatmap(data=data.iloc[:,2:4])
# Out:
# <AxesSubplot:>

# %%
data.loc[data['Salary'].isnull()|data['Bonus %'].isnull()]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Salary, Bonus %, Senior Management, Team, Gnder_check, var]
# Index: []

# %%
data=data.drop(columns=['Gnder_check', 'var'])
data
# Out:
#     First Name  Gender  Salary  Bonus % Senior Management  \
# 0      Douglas    Male   97308    6.945              True
# 1       Thomas    Male   61933    4.170              True
# 2        Maria  Female  130590   11.858             False
# 3        Jerry    Male  138705    9.340              True
# 4        Larry    Male  101004    1.389              True
# ..         ...     ...     ...      ...               ...
# 995      Henry    Male  132483   16.655             False
# 996    Phillip    Male   42392   19.675             False
# 997    Russell    Male   96914    1.421             False
# 998      Larry    Male   60500   11.985             False
# 999     Albert    Male  129949   10.169              True
#
#                      Team
# 0               Marketing
# 1                     NaN
# 2                 Finance
# 3                 Finance
# 4         Client Services
# ..                    ...
# 995          Distribution
# 996               Finance
# ...

# %%
data['indicator'] = np.round((data['Bonus %']/100)*data['Salary'],2)
data
# Out:
#     First Name  Gender  Salary  Bonus % Senior Management  \
# 0      Douglas    Male   97308    6.945              True
# 1       Thomas    Male   61933    4.170              True
# 2        Maria  Female  130590   11.858             False
# 3        Jerry    Male  138705    9.340              True
# 4        Larry    Male  101004    1.389              True
# ..         ...     ...     ...      ...               ...
# 995      Henry    Male  132483   16.655             False
# 996    Phillip    Male   42392   19.675             False
# 997    Russell    Male   96914    1.421             False
# 998      Larry    Male   60500   11.985             False
# 999     Albert    Male  129949   10.169              True
#
#                      Team  indicator
# 0               Marketing    6758.04
# 1                     NaN    2582.61
# 2                 Finance   15485.36
# 3                 Finance   12955.05
# 4         Client Services    1402.95
# ..                    ...        ...
# ...

# %%
plt.figure(figsize=(18,10))

sns.boxplot(x=data['Team'], y=data['indicator'])
# Out:
# <AxesSubplot:xlabel='Team', ylabel='indicator'>

# %%
plt.figure(figsize=(14,6))
sns.histplot(x=data['indicator'], hue=data['Team'])
# Out:
# <AxesSubplot:xlabel='indicator', ylabel='Count'>

# %%
data['indicator'] = data['indicator'].apply(lambda x: np.round(x,2))

# %%
means = data.groupby('Team', as_index=False)['indicator'].mean().round(2)

# %%
means
# Out:
#                    Team  indicator
# 0  Business Development    9586.59
# 1       Client Services    9051.08
# 2          Distribution    8521.48
# 3           Engineering    9637.49
# 4               Finance    9163.50
# 5       Human Resources    8903.86
# 6                 Legal    9504.21
# 7             Marketing    9253.09
# 8               Product    8925.07
# 9                 Sales    9326.25

# %%
medians = data.groupby('Team', as_index=False)['indicator'].median().round(2)

# %%
medians
# Out:
#                    Team  indicator
# 0  Business Development    8043.44
# 1       Client Services    8178.95
# 2          Distribution    7449.80
# 3           Engineering    8874.28
# 4               Finance    7744.92
# 5       Human Resources    7393.80
# 6                 Legal    8384.20
# 7             Marketing    6910.96
# 8               Product    7410.43
# 9                 Sales    8032.95

# %%
data['Team'] = data['Team'].fillna("No Data")

# %%
data.isnull().sum()
# Out:
# First Name            0
# Gender                0
# Salary                0
# Bonus %               0
# Senior Management    67
# Team                  0
# indicator             0
# dtype: int64

# %%
data['Senior Management'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
trues = data[data['Senior Management']==True]

# %%
data[data['Senior Management']==False].shape[0]
# Out:
# 465

# %%
data['Senior Management'] = data['Senior Management'].fillna('No Data')
data.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# indicator            0
# dtype: int64

# %%
data['Senior Management'] = data['Senior Management'].replace(True, "Yes")
data['Senior Management'] = data['Senior Management'].replace(False, "No")

# %%
data
# Out:
#     First Name  Gender  Salary  Bonus % Senior Management  \
# 0      Douglas    Male   97308    6.945               Yes
# 1       Thomas    Male   61933    4.170               Yes
# 2        Maria  Female  130590   11.858                No
# 3        Jerry    Male  138705    9.340               Yes
# 4        Larry    Male  101004    1.389               Yes
# ..         ...     ...     ...      ...               ...
# 995      Henry    Male  132483   16.655                No
# 996    Phillip    Male   42392   19.675                No
# 997    Russell    Male   96914    1.421                No
# 998      Larry    Male   60500   11.985                No
# 999     Albert    Male  129949   10.169               Yes
#
#                      Team  indicator
# 0               Marketing    6758.04
# 1                 No Data    2582.61
# 2                 Finance   15485.36
# 3                 Finance   12955.05
# 4         Client Services    1402.95
# ..                    ...        ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   object
#  2   Salary             1000 non-null   int64
#  3   Bonus %            1000 non-null   float64
#  4   Senior Management  1000 non-null   object
#  5   Team               1000 non-null   object
#  6   indicator          1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 54.8+ KB

# %%
plt.scatter(x=data['Salary'], y=data['Bonus %'])

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# First Name           0
# Gender               0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# indicator            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         1000 non-null   object
#  1   Gender             1000 non-null   object
#  2   Salary             1000 non-null   int64
#  3   Bonus %            1000 non-null   float64
#  4   Senior Management  1000 non-null   object
#  5   Team               1000 non-null   object
#  6   indicator          1000 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 62.5+ KB

# %%
data['Salary'] = data['Salary'].astype(int)
data['Bonus %'] = data['Bonus %'].astype(int)
data = data.drop(columns=['indicator'])

data.head(10)
# Out:
#   First Name  Gender  Salary  Bonus % Senior Management                  Team
# 0    Douglas    Male   97308        6               Yes             Marketing
# 1     Thomas    Male   61933        4               Yes               No Data
# 2      Maria  Female  130590       11                No               Finance
# 3      Jerry    Male  138705        9               Yes               Finance
# 4      Larry    Male  101004        1               Yes       Client Services
# 5     Dennis    Male  115163       10                No                 Legal
# 6       Ruby  Female   65476       10               Yes               Product
# 7    No Name  Female   45906       11           No Data               Finance
# 8     Angela  Female   95570       18               Yes           Engineering
# 9    Frances  Female  139852        7               Yes  Business Development

# %%
data.Team.value_counts(ascending=True).plot(kind='barh')
plt.title('Count of departments analysed')
# Out:
# Text(0.5, 1.0, 'Count of departments analysed')

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data['Team'], y=data['Salary'])
plt.title('Salaries average per department')
# Out:
# Text(0.5, 1.0, 'Salaries average per department')

# %%
average_salaries = data.groupby('Team')['Salary'].mean().round(2)

# %%
sns.barplot(x=average_salaries.values, y=average_salaries.index)
# Out:
# <AxesSubplot:ylabel='Team'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=data['Bonus %'], y=data['Gender'])
# Out:
# <AxesSubplot:xlabel='Bonus %', ylabel='Gender'>

# %%
Female = data[data['Gender']=='Female']
Male = data[data['Gender']=='Male']

Average1 = np.round(Female['Bonus %'].mean(),2)
Average2 = np.round(Male['Bonus %'].mean(),2)

print('The average Bonus per Gender:\n\nFemale: {0}%\nMale:{1}%'.format(Average1, Average2))
# Out:
# The average Bonus per Gender:
#
# Female: 9.56%
# Male:9.86%

# %%
fig = plt.figure(figsize=(20,10))

plt.subplot(2,1,1)
sns.boxplot(x=Female['Team'], y=Female['Bonus %'])
plt.subplot(2,1,2)
sns.boxplot(x=Male['Team'], y=Male['Bonus %'])

plt.show()

# %%
plt.figure(figsize=(22,8))
sns.boxplot(x=data['Team'], y=data['Bonus %'], hue=data['Gender'])
plt.legend(bbox_to_anchor=(1,1),loc='upper left')
plt.show()
